# %%
import pandas as pd 

# Control delimiters, rows, column names with read_csv (see later) 
data = pd.read_csv("C:\\Users\\Grayson\\Documents\\esg_scoring\\dat_stocks.csv", encoding='latin-1') 
# Preview the first 5 lines of the loaded data 
data.head()
# Out:
#   ticker              company                  sector  \
# 0    MMM           3M Company             Industrials
# 1    ABT  Abbott Laboratories             Health Care
# 2   ABBV          AbbVie Inc.             Health Care
# 3   ABMD          ABIOMED Inc             Health Care
# 4    ACN        Accenture plc  Information Technology
#
#                          industry esgRating  esgScore.tot  esgScore.env  \
# 0        Industrial Conglomerates      High          35.0          12.8
# 1           Health Care Equipment    Medium          30.0           3.0
# 2                 Pharmaceuticals      High          31.0           1.0
# 3           Health Care Equipment       NaN           NaN           NaN
# 4  IT Consulting & Other Services       Low          11.0           0.6
#
#    esgScore.soc  esgScore.gov  esgRank.tot  esgRank.env  esgRank.soc  \
# 0          13.9           8.1         0.72          NaN          NaN
# 1          16.2          10.6         0.56          NaN          NaN
# 2          18.0          12.3         0.61          NaN          NaN
# 3           NaN           NaN          NaN          NaN          NaN
# 4           5.0           5.7         0.02          NaN          NaN
#
#    esgRank.gov  conRating  conLevel  conAreas        asOf
# 0          NaN        NaN       NaN       NaN  2020-09-11
# 1          NaN        NaN       NaN       NaN  2020-09-11
# 2          NaN        NaN       NaN       NaN  2020-09-11
# 3          NaN        NaN       NaN       NaN         NaN
# 4          NaN        NaN       NaN       NaN  2020-09-11

# %%
import subprocess

# %%
import rpy2.robjects as robjects
r_source = robjects.r['source']
r_source(‘esg_scoring.R’)
# Out:
#   File "<ipython-input-56-ecd729a5a202>", line 3
#     r_source(‘esg_scoring.R’)
#                         ^
# SyntaxError: invalid character in identifier
